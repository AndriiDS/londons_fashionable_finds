# %%
import os
print(os.getcwd())
# Out:
# /Users/andrii/Documents/londons_fashionable_finds/04_Model

# %%
os.chdir('/Users/andrii/Documents/londons_fashionable_finds')

# %%
import pandas as pd

# Load the CSV into a DataFrame
shops = pd.read_csv('03_Feature_Engineering/shops.csv')
shops = shops.drop(columns=['Unnamed: 0'])

# %%
from IPython.display import display

display(shops)
# Out:
#                         Shop_Name
# 0               Vintage80scasuals  \
# 1              Accessories of Old
# 2             Eclectica (Clapham)
# 3                  BajaboutiqueGB
# 4     INSIGHT Fulham Dress Agency
# ..                            ...
# 637                 Little Crumbs
# 638       Isabella Bazaar Dalston
# 639        Oxfam Shop Walthamstow
# 640  The Salvation Army (Clapton)
# 641                        Age UK
#
#                                            Address   Latitude  Longitude
# 0                  Unit 63, 105 Culvert Rd, London  51.470904  -0.156681  \
# 1    Next to Safestore, Arch 10 Munster Rd, London  51.472579  -0.203859
# 2                        803 Wandsworth Rd, London  51.466581  -0.148460
# 3                               37 Elbe St, London  51.472878  -0.185076
# 4                           201 Munster Rd, London  51.479447  -0.211883
# ..                                             ...        ...        ...
# 637                      194 Balls Pond Rd, London  51.546717  -0.086736
# 638                       500 Kingsland Rd, London  51.543723  -0.075801
# 639                            2-4 High St, London  51.581558  -0.033495
# 640                   122 Lower Clapton Rd, London  51.554421  -0.053815
# 641                          36/44 High St, London  51.581862  -0.031678
#
#        Rating                 Borough  Property_Value_2017  Earnings_2021
# 0    4.287722              Wandsworth             640000.0          746.7
# 1    4.287722  Hammersmith and Fulham             740000.0          714.5
# 2    4.900000                 Lambeth             510000.0          673.6
# 3    4.287722  Hammersmith and Fulham             740000.0          714.5
# 4    5.000000  Hammersmith and Fulham             740000.0          714.5
# ..        ...                     ...                  ...            ...
# 637  3.800000               Islington             625000.0          665.6
# 638  4.287722                 Hackney             530000.0          575.1
# 639  4.000000          Waltham Forest             430000.0          624.7
# 640  4.900000                 Hackney             530000.0          575.1
# 641  4.000000          Waltham Forest             430000.0          624.7
#
# [642 rows x 8 columns]

# %%
shops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642 entries, 0 to 641
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Shop_Name            642 non-null    object
#  1   Address              642 non-null    object
#  2   Latitude             642 non-null    float64
#  3   Longitude            642 non-null    float64
#  4   Rating               642 non-null    float64
#  5   Borough              642 non-null    object
#  6   Property_Value_2017  642 non-null    float64
#  7   Earnings_2021        642 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 40.2+ KB

# %%
import pandas as pd

# Define the importance weights for each factor
weight_rating = 0.4
weight_property_value = 0.3
weight_earnings = 0.3

# Calculate the composite score for each shop using the weighted scoring model
shops['composite_score'] = (shops['Rating'] * weight_rating) + \
                                   (shops['Property_Value_2017'] * weight_property_value) + \
                                   (shops['Earnings_2021'] * weight_earnings)

# Rank the shops by composite score in descending order
ranked_shops = shops.sort_values('composite_score', ascending=False)

# %%
# Print the top 10 shops by composite score
display(ranked_shops.head(10))
# Out:
#                                      Shop_Name
# 78                       This Old Thing London  \
# 59                              Oliver Vintage
# 76                          Vintage Fur Garden
# 25                      Vittorio Ragone Design
# 68                            vintage clothing
# 369  Royal Trinity Hospice - Earl's Court shop
# 57                       Antique Clothing Shop
# 395        Vision Foundation - Portobello Road
# 39         AntikBar - Original Vintage Posters
# 29                                     Hornets
#
#                                                Address   Latitude  Longitude
# 78                            79 Portobello Rd, London  51.512732  -0.202126  \
# 59   Unit 7, Portobello Green Arcade, 281 Portobell...  51.518562  -0.207352
# 76                            82 Portobello Rd, London  51.512678  -0.201661
# 25                               533 King's Rd, London  51.480272  -0.185448
# 68                                              London  51.523625  -0.206717
# 369                            202 Earls Ct Rd, London  51.492624  -0.193999
# 57                           282 Portobello Rd, London  51.519292  -0.207412
# 395                          235 Portobello Rd, London  51.517032  -0.206121
# 39                               404 King's Rd, London  51.483615  -0.177151
# 29                2 & 4 Kensington Church Walk, London  51.502533  -0.192820
#
#      Rating                 Borough  Property_Value_2017  Earnings_2021
# 78      5.0  Kensington and Chelsea            1200000.0          767.0  \
# 59      5.0  Kensington and Chelsea            1200000.0          767.0
# 76      5.0  Kensington and Chelsea            1200000.0          767.0
# 25      5.0  Kensington and Chelsea            1200000.0          767.0
# 68      5.0  Kensington and Chelsea            1200000.0          767.0
# 369     5.0  Kensington and Chelsea            1200000.0          767.0
# 57      5.0  Kensington and Chelsea            1200000.0          767.0
# 395     5.0  Kensington and Chelsea            1200000.0          767.0
# 39      4.9  Kensington and Chelsea            1200000.0          767.0
# 29      4.9  Kensington and Chelsea            1200000.0          767.0
#
#      composite_score
# 78         360232.10
# 59         360232.10
# 76         360232.10
# 25         360232.10
# 68         360232.10
# 369        360232.10
# 57         360232.10
# 395        360232.10
# 39         360232.06
# 29         360232.06
